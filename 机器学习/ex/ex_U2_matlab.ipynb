# %% [markdown]
# # 《零基础学机器学习》练习--U2
#
#
# TODO：作图y=2x+1，还没有完全完成

# %%
import matplotlib.pyplot as plt 
import numpy as np 

x = np.linspace(-10, 10, 100)
y = 2*x+1


fig, axes = plt.subplots(figsize=(5, 5))
plt.xlabel("x")
plt.ylabel("y")
plt.plot(x, y, linestyle = 'dotted')
plt.annotate("JieJu", xy=(0, 1))
# axes[0].set_yticks([-10, 10, 1])
plt.show()

# %% [markdown]
# # 第四题见ex_U1_boston_housing.ipynb

# %%
# 第五题：学习张量的点积操作

A = np.arange(1, 6, 1)
B = np.array([[5], [4], [3], [2], [1]])

print(A.shape)
print(A)

print(B.shape)

C = A.dot(B)
D = A*B
print(C)
print(D)
# Out:
# (5,)
# [1 2 3 4 5]
# (5, 1)
# [35]
# [[ 5 10 15 20 25]
#  [ 4  8 12 16 20]
#  [ 3  6  9 12 15]
#  [ 2  4  6  8 10]
#  [ 1  2  3  4  5]]
