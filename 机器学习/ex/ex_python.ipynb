# %% [markdown]
# # 练习Python的使用

# %%
# Conditionals on iterable
num1 = [5,10,15]
num3 = [i**2 if i == 10 else i-5 for i in num1]
print(num3)

num4 = [i**2 if i == 10 else i if i < 7 else i+5 for i in num1]
print(num4)

num2 = [i**2 if i == 10 else i-5 if i < 7 else i+5 for i in num1]
print(num2)
# Out:
# [0, 100, 10]
# [5, 100, 20]
# [0, 100, 20]
